# %%
import pandas as pd
import pylab as pl
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import numpy as np

# %%
data_frame = pd.read_csv("quakes.csv")

data_frame.head()
# Out:
#                   time   latitude   longitude  depth   mag magType   nst  \
# 0  2019-02-10 04:34:16  33.093833 -116.033333   9.55  0.87      ml  18.0
# 1  2019-02-10 04:29:47  35.801800 -116.460700   4.00  2.10      ml  13.0
# 2  2019-02-10 04:29:28  34.709167 -116.285833   2.19  2.83      ml  24.0
# 3  2019-02-10 04:28:00  63.444300 -147.559100   3.90  1.60      ml   NaN
# 4  2019-02-10 04:10:07  47.964167 -122.378500  27.13  2.33      ml  19.0
#
#       gap    dmin   rms    ...                      updated  \
# 0   64.00  0.1287  0.28    ...     2019-02-10T04:37:55.802Z
# 1  276.24  0.1660  0.14    ...     2019-02-10T04:31:15.319Z
# 2   59.00  0.1138  0.17    ...     2019-02-10T04:33:08.980Z
# 3     NaN     NaN  0.68    ...     2019-02-10T04:31:45.405Z
# 4   75.00     NaN  0.14    ...     2019-02-10T04:22:28.600Z
#
#                              place        type horizontalError depthError  \
# 0   11km ESE of Ocotillo Wells, CA  earthquake            0.56       2.15
# 1       62km SW of Pahrump, Nevada  earthquake             NaN       7.30
# 2             12km W of Ludlow, CA  earthquake            0.28       0.73
# 3       69km E of Cantwell, Alaska  earthquake             NaN       0.40
# 4  5km WNW of Mukilteo, Washington  earthquake            0.41       1.06
#
#    magError  magNst     status  locationSource magSource
# 0  0.109000    12.0  automatic              ci        ci
# 1       NaN     NaN  automatic              nn        nn
# 2  0.155000    24.0  automatic              ci        ci
# 3       NaN     NaN  automatic              ak        ak
# 4  0.194838    11.0   reviewed              uw        uw
#
# [5 rows x 22 columns]

# %%
data_frame[['mag','depth']].hist()
plt.show()

# %%
x = data_frame[['mag','depth']]
# y = data_frame['depth']

x
# Out:
#        mag   depth
# 0     0.87    9.55
# 1     2.10    4.00
# 2     2.83    2.19
# 3     1.60    3.90
# 4     2.33   27.13
# 5     4.50  141.31
# 6     0.97    3.92
# 7     1.50   41.50
# 8     1.80   48.80
# 9     0.73   11.60
# 10    5.20   10.00
# 11    0.56    4.59
# 12    0.66    3.64
# 13    0.83    3.67
# 14    4.70   10.00
# 15    0.42    2.29
# 16    1.80   16.80
# 17    0.75    4.97
# 18    1.81   -0.50
# 19    0.90    3.86
# 20    1.27   11.85
# 21    1.44    7.12
# 22    1.30   40.30
# 23    1.60    0.80
# 24    2.90    0.10
# 25    1.20   47.60
# 26    5.20   44.08
# 27    2.10    4.80
# 28    4.50   35.00
# 29    0.78   21.44
# ...    ...     ...
# 1669  0.40    9.90
# 1670  0.99   12.31
# 1671  2.83    7.13
# 1672  5.40   35.00
# 1673  1.60   12.40
# 1674  1.30   38.00
# 1675  3.30    5.30
# 1676  3.31   40.00
# 1677  0.83    6.56
# 1678  1.90   24.30
# 1679  1.70   75.40
# 1680  1.60    2.10
# 1681  0.82    6.00
# 1682  1.62   14.90
# 1683  4.60   10.00
# 1684  1.00    4.83
# 1685  1.90   81.00
# 1686  4.90   35.00
# 1687  4.30   10.00
# 1688  1.05    6.94
# 1689  1.07   10.79
# 1690  0.98    8.57
# 1691  1.31    5.16
# 1692  1.10    7.30
# 1693  2.10   30.60
# 1694  2.46    6.92
# 1695  0.20    4.10
# 1696  3.00    5.00
# 1697  5.10   48.31
# 1698  2.14   72.00
#
# [1699 rows x 2 columns]

# %%
# x=x.values.reshape(-1, 1)
x = np.array(x)

# %%
x
# Out:
# array([[ 0.87,  9.55],
#        [ 2.1 ,  4.  ],
#        [ 2.83,  2.19],
#        ...,
#        [ 3.  ,  5.  ],
#        [ 5.1 , 48.31],
#        [ 2.14, 72.  ]])

# %%
Nc = range(1, 20)

kmeans = [KMeans(n_clusters=i) for i in Nc]

kmeans

score = [kmeans[i].fit(x).score(x) for i in range(len(kmeans))]

score
# Out:
# [-3080444.5334801646,
#  -1402116.1802490903,
#  -594173.6121221026,
#  -302845.5036088041,
#  -191243.1376080417,
#  -135063.49996669096,
#  -100134.08223311296,
#  -74903.17715535781,
#  -58534.11323909482,
#  -48264.74360757845,
#  -41647.21058768281,
#  -35092.68170136034,
#  -31949.160134660353,
#  -26961.221220167517,
#  -23788.199989918787,
#  -20351.265277157196,
#  -17729.532907481247,
#  -15215.361172402187,
#  -13577.864063391571]

# %%
pl.plot(Nc,score)

pl.xlabel('Number of Clusters')

pl.ylabel('Score')

pl.title('Elbow Curve')

pl.show()

# %%
kmeans=KMeans(n_clusters=5)

kmeansoutput_x=kmeans.fit(x)
# kmeansoutput_y=kmeans.fit(y)
# kmeansoutput_z=kmeans.fit(z)

type(kmeansoutput_x)
# type(kmeansoutput_y)
# type(kmeansoutput_z)
# Out:
# sklearn.cluster.k_means_.KMeans

# %%
pl.figure('5 Cluster K-Means')


pl.scatter(x[:,0],x[:,1], c=kmeansoutput_x.labels_, cmap='rainbow')

pl.title('5 Cluster K-Means')
pl.xlabel('Magnitude')

pl.ylabel('Depth')


pl.show()
